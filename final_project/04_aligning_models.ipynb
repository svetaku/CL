# %%
import numpy as np
import fasttext
import operator

def normalized(a, axis=-1, order=2):
    """Utility function to normalize the rows of a numpy array."""
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

def make_training_matrices(source_dictionary, target_dictionary, bilingual_dictionary):
    """
    Source and target dictionaries are the FastVector objects of
    source/target languages. bilingual_dictionary is a list of 
    translation pair tuples [(source_word, target_word), ...].
    """
    source_matrix = []
    target_matrix = []

    for (source, target) in bilingual_dictionary:
        if source in source_dictionary and target in target_dictionary:
            source_matrix.append(source_dictionary[source])
            target_matrix.append(target_dictionary[target])

    # return training matrices
    return np.array(source_matrix), np.array(target_matrix)

def learn_transformation(source_matrix, target_matrix, normalize_vectors=True):
    """
    Source and target matrices are numpy arrays, shape
    (dictionary_length, embedding_dimension). These contain paired
    word vectors from the bilingual dictionary.
    """
    # optionally normalize the training vectors
    if normalize_vectors:
        source_matrix = normalized(source_matrix)
        target_matrix = normalized(target_matrix)

    # perform the SVD
    product = np.matmul(source_matrix.transpose(), target_matrix)
    U, s, V = np.linalg.svd(product)

    # return orthogonal transformation which aligns source language to the target
    return np.matmul(U, V)

class FastVector:
    def __init__(self, vector_file='', transform=None):
        self.word2id = {}
        self.id2word = []

        print('reading word vectors from %s' % vector_file)
        with open(vector_file, 'r') as f:
            (self.n_words, self.n_dim) = \
                (int(x) for x in f.readline().rstrip('\n').split(' '))
            self.embed = np.zeros((self.n_words, self.n_dim))
            for i, line in enumerate(f):
                elems = line.rstrip('\n').split(' ')
                self.word2id[elems[0]] = i
                self.embed[i] = elems[1:self.n_dim+1]
                self.id2word.append(elems[0])

        if transform is not None:
            print('Applying transformation to embedding')
            self.apply_transform(transform)

    def apply_transform(self, transform):
        transmat = np.loadtxt(transform) if isinstance(transform, str) else transform
        self.embed = np.matmul(self.embed, transmat)

    def export(self, outpath):

        fout = open(outpath, "w")

        fout.write(str(self.n_words) + " " + str(self.n_dim) + "\n")
        for token in self.id2word:
            vector_components = ["%.6f" % number for number in self[token]]
            vector_as_string = " ".join(vector_components)

            out_line = token + " " + vector_as_string + "\n"
            fout.write(out_line)

        fout.close()
    def translate_nearest_neighbour(self, source_vector):
        """Obtain translation of source_vector using nearest neighbour retrieval"""
        similarity_vector = np.matmul(FastVector.normalised(self.embed), source_vector)
        target_id = np.argmax(similarity_vector)
        return self.id2word[target_id]

    def translate_inverted_softmax(self, source_vector, source_space, nsamples,
                                   beta=10., batch_size=100, recalculate=True):
        """
        Obtain translation of source_vector using sampled inverted softmax retrieval
        with inverse temperature beta.
        nsamples vectors are drawn from source_space in batches of batch_size
        to calculate the inverted softmax denominators.
        Denominators from previous call are reused if recalculate=False. This saves
        time if multiple words are translated from the same source language.
        """
        embed_normalised = FastVector.normalised(self.embed)
        # calculate contributions to softmax denominators in batches
        # to save memory
        if self.softmax_denominators is None or recalculate is True:
            self.softmax_denominators = np.zeros(self.embed.shape[0])
            while nsamples > 0:
                # get batch of randomly sampled vectors from source space
                sample_vectors = source_space.get_samples(min(nsamples, batch_size))
                # calculate cosine similarities between sampled vectors and
                # all vectors in the target space
                sample_similarities = \
                    np.matmul(embed_normalised,
                              FastVector.normalised(sample_vectors).transpose())
                # accumulate contribution to denominators
                self.softmax_denominators \
                    += np.sum(np.exp(beta * sample_similarities), axis=1)
                nsamples -= batch_size
        # cosine similarities between source_vector and all target vectors
        similarity_vector = np.matmul(embed_normalised,
                                      source_vector/np.linalg.norm(source_vector))
        # exponentiate and normalise with denominators to obtain inverted softmax
        softmax_scores = np.exp(beta * similarity_vector) / \
                         self.softmax_denominators
        # pick highest score as translation
        target_id = np.argmax(softmax_scores)
        return self.id2word[target_id]

    def get_samples(self, nsamples):
        """Return a matrix of nsamples randomly sampled vectors from embed"""
        sample_ids = np.random.choice(self.embed.shape[0], nsamples, replace=False)
        return self.embed[sample_ids]
    
    @classmethod
    def normalised(cls, mat, axis=-1, order=2):
        """Utility function to normalise the rows of a numpy array."""
        norm = np.linalg.norm(
            mat, axis=axis, ord=order, keepdims=True)
        norm[norm == 0] = 1
        return mat / norm


    @classmethod
    def cosine_similarity(cls, vec_a, vec_b):
        """Compute cosine similarity between vec_a and vec_b"""
        return np.dot(vec_a, vec_b) / \
            (np.linalg.norm(vec_a) * np.linalg.norm(vec_b))

    def __contains__(self, key):
        return key in self.word2id

    def __getitem__(self, key):
        return self.embed[self.word2id[key]]

# %%
ruen = open("ru-en2.txt", encoding="utf-8").read()

ruen_list = ruen.split()
enru_dict = []
for ind in range(len(ruen_list)):
    if ind % 2 == 0:
        pair = (ruen_list[ind+1], ruen_list[ind])
        enru_dict.append(pair)

# %%
en_dictionary = FastVector(vector_file='en_model_fb.vec')
ru_dictionary = FastVector(vector_file='ru_model_fb.vec')
# Out:
# reading word vectors from en_model_fb.vec
# reading word vectors from ru_model_fb.vec

# %%
# form the training matrices
source_matrix, target_matrix = make_training_matrices(en_dictionary, ru_dictionary, enru_dict)

# learn and apply the transformation
transform = learn_transformation(source_matrix, target_matrix)
en_dictionary.apply_transform(transform)

# %%
en_vector = en_dictionary["key"]
ru_vector = ru_dictionary["ключ"]
print(FastVector.cosine_similarity(en_vector, ru_vector))
# Out:
# 0.7919760657988609

# %%
ru_dictionary.translate_nearest_neighbour(en_dictionary["hotel"])
# Out:
# 'отель'

# %%
import pickle
with open('D:\\python\\CL\\gob\\keywords_short.pkl', 'rb') as f:
    keywords = pickle.load(f)

# %%
import pandas as pd

data = pd.read_csv('D:\\python\\CL\\gob\\pi2.csv', sep=';', low_memory=False)
data = data[['string_id','Russian', 'English']]
index_names = data[data['Russian'].str.contains("тест" or "test")==True].index
# # index_names
data.drop(index_names, inplace = True)
data = data.dropna()
data = data.drop_duplicates()
data = data[data.Russian != data.English]
index_names2 = data[data['string_id'].str.contains("achieve", "title") ==True].index
data.drop(index_names2, inplace = True)
data = data[['Russian', 'English']].drop_duplicates()
data_dict = pd.Series(data.Russian.values,index=data.English).to_dict()

# %%
data_with_keyword = data[data['English'].str.lower().str.contains("key")]
russian = data_with_keyword.iloc[15]["Russian"]
for word in preprocess_text_ru(russian).split():
    ru_vector = ru_dictionary[word]
    print(word, FastVector.cosine_similarity(en_dictionary["key"], ru_vector))
# Out:
# открыть 0.6342611412358431
# замок 0.5073786675186719
# ключ 0.7919760657988609
# спасти 0.4275333458327296
# зверюшка 0.6906345955807068

# %%
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
import re
import nltk
from nltk.corpus import stopwords

def preprocess_text_ru(item):
    item = re.sub(r"\d+%", " ", item)
    item = re.sub(r"x\d+", " ", item)
    item = re.sub(r"\d+", " ", item)
    item = re.sub(r"\n", " ", item)
    item = re.sub(r"\[.+\]", " ", item)
    item = re.sub(r"\\.+\\;", " ", item)
    item = re.sub(r"http.+", " ", item)
    item = re.sub(r"\{.*\}", " ", item)
    item = re.sub(r" [xX] ", " ", item)
    item = re.sub(r"%[sd]", " ", item)
    item = re.sub(r"<.+>", " ", item)
    item = re.sub(r"[\U00010000-\U0010ffff]", " ", item)
    item = re.sub(r"[!@#$%\^\&\*()_=+\?\!:;\",\.\\»«—№]", " ", item)
    item = re.sub(r"\s+", " ", item)
    item = item.strip(' ')
    item = item.lower()
    
     # Lemmatization
#     punct = ".!:?"
#     try:
#         if item[-1] not in punct:
#             item = item + "."
#     except Exception:
#         pass
    tokens = item.split()
    tokens = [morph.parse(word)[0].normal_form for word in tokens]
    tokens = [word for word in tokens if word not in stopwords.words('russian')]
#     tokens = [word for word in tokens if len(word) > 3]

    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
def preprocess_text_en(item):
    item = re.sub(r"\d+%", " ", item)
    item = re.sub(r"x\d+", " ", item)
    item = re.sub(r"\d+", " ", item)
    item = re.sub(r"\n", " ", item)
    item = re.sub(r"\[.+\]", " ", item)
    item = re.sub(r"\\+.+;", " ", item)
    item = re.sub(r"http.+", " ", item)
    item = re.sub(r"\{.*\}", " ", item)
    item = re.sub(r" [xX] ", " ", item)
    item = re.sub(r"%[sd]", " ", item)
    item = re.sub(r"<.+>", " ", item)
    item = re.sub(r"[\U00010000-\U0010ffff]", " ", item)
    item = re.sub(r"[!@#$%\^\&\*()_=+\?\!:;\",\.\\»«—-]", " ", item)
    item = re.sub(r"\s+", " ", item)
    item = item.strip(' ')
    item = item.lower()
    
     # Lemmatization
#     punct = ".!:?"
#     try:
#         if item[-1] not in punct:
#             item = item + "."
#     except Exception:
#         pass
    tokens = item.split()
    tokens = [nlp(word)[0].lemma_ if word != "flowerbed" else "flowerbed" for word in tokens]
#     tokens = [word for word in tokens if nltk.pos_tag([word])[0][1] == "NN" or "NNP"]
    tokens = [word for word in tokens if word not in stopwords.words('english')]
#     tokens = [word for word in tokens if len(word) > 3]

    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
from collections import Counter

# %%
termbase = {}
keyvsru = {}
for keyword in list(keywords):
#     print(keyword)
    data_with_keyword = data[data['English'].str.lower().str.contains(keyword) == True]
    data_dict = pd.Series(data_with_keyword.Russian.values,index=data_with_keyword.English).to_dict()
    data_ru = []
    for x in data_dict:
        clean_string = preprocess_text_en(x)
        if keyword in clean_string.split():
            data_ru.append(data_dict[x])
    term_corpus = [preprocess_text_ru(sentence) for sentence in data_ru if len(sentence) < 80]
    data_ru_str = ' '.join(term_corpus)
    ru_pool = Counter(data_ru_str.split()).most_common(3)
    ru_keys = [key for key, val in ru_pool]
    cos_dict = {}
    for word in ru_keys:
        try:
            ru_vector = ru_dictionary[word]
            cos_dict[word] = FastVector.cosine_similarity(en_dictionary[keyword], ru_vector)
        except:
            continue
    try:
        translation = max(cos_dict.items(), key=operator.itemgetter(1))[0]
        termbase[keyword] = translation
    except:
        continue
        
    keyvsru[keyword] = ru_keys
print(keyvsru)
termbase
# Out:
# {'turtle': ['черепаха', 'черепашка', 'черепашонка'], 'past': ['прошлое', 'старый', 'победитель'], 'head': ['голова', 'остров', 'беда'], 'statuette': ['статуэтка', 'подарок', 'уникальный'], 'reduce': ['прибыль', 'здание', 'персонал'], 'candy': ['леденец', 'сладкий', 'любовный'], 'shuttle': ['мяу-шаттл', 'шаттл', 'сломать'], 'bunch': ['гроздь', 'букет', 'цвет'], 'surprise': ['сюрприз', 'открыть', 'получить'], 'mistake': ['ошибка', 'сыграть', 'совершить'], 'area': ['территория', 'купить', 'восточный'], 'bridge': ['мост', 'спасти', 'получить'], 'tea': ['чай', 'чаепитие', 'чайный'], 'tap': ['нажать', 'начать', 'сундук'], 'heart': ['сердце', 'сердечко', 'шоколадный'], 'pirate': ['пиратский', 'яхта', 'пират'], 'clean': ['уборка', 'порядок', 'это'], 'museum': ['музей', 'остров', 'провести'], 'fairy': ['фея', 'винтербелла', 'получить'], 'break': ['разбить', 'хотеть', 'здание'], 'cake': ['торт', 'тропический', 'кусочек'], 'launch': ['запустить', 'нажать', 'событие'], 'winner': ['победитель', 'медаль', 'собрать'], 'merry': ['весёлый', 'отель', 'бочонок'], 'lightning': ['молния', 'радужный', 'тортильяд'], 'happen': ['событие', 'случиться', 'отель'], 'score': ['комбо', 'набрать', 'получить'], 'mastery': ['мастерство', 'уровень', 'создание'], 'cozy': ['уютный', 'дворик', 'построить'], 'unioner': ['союзник', 'союз', 'битва'], 'jam': ['джема', 'варение', 'банановый'], 'news': ['новость', 'отличный', 'интересный'], 'architect': ['архитектор', 'кастлинга', 'получить'], 'expand': ['расширить', 'площадь', 'здание'], 'float': ['парить', 'замок', 'здание'], 'package': ['посылка', 'зелёный', 'открыть'], 'cruise': ['лайнер', 'круизный', 'катер'], 'florist': ['флорист', 'вечер', 'зависть'], 'remove': ['убрать', 'извлечь', 'аксессуар'], 'activate': ['активировать', 'бонус', 'достигнуть'], 'health': ['здоровье', 'награда', 'каждый'], 'thank': ['спасибо', '-', 'это'], 'design': ['чертёж', 'старинный', 'создать'], 'passion': ['страсть', '-', 'отель'], 'meyer': ['сидень', 'мейер', 'сыграть'], 'lao': ['лао', 'дао', 'подарок'], 'friend': ['друг', 'подарок', 'отправить'], 'tournament': ['турнир', 'faq', 'рейтинг'], 'chocolate': ['шоколадный', 'шоколад', 'шоколадка'], 'chance': ['шанс', 'хотеть', 'снизить'], 'chapter': ['глава', 'завершить', 'сначала'], 'water': ['вода', 'водный', 'водяной'], 'bear': ['панда', 'больший', 'мишка'], 'yellow': ['жёлтый', 'фишка', 'собрать'], 'journey': ['путешествие', 'сезон', 'зимний'], 'error': ['ошибка', 'произойти', 'сообщать'], 'generator': ['генератор', 'квантовый', 'снег'], 'celebration': ['праздник', '-', 'подарок'], 'bouquet': ['букет', 'весенний', 'конкурс'], 'rating': ['рейтинг', 'здание', 'звёздность'], 'effort': ['усилие', 'старание', 'отлично'], 'touch': ['палец', '-', 'наш'], 'difficulty': ['сложность', 'уровень', 'рию'], 'sinister': ['зловещий', 'бокс', 'дуб'], 'sunshine': ['центр', 'саншайн', 'солнечный'], 'feeling': ['чувство', 'свой', 'настроение'], 'chameleon': ['хамелеон', 'говорить', 'погладить'], 'leprechaun': ['лепрекон', 'лепреконовый', 'получить'], 'builder': ['строитель', 'каска', 'использовать'], 'vi': ['vi', 'сезон', 'битва'], 'sailor': ['матрос', 'получить', 'джесси'], 'click': ['нажать', 'начать', 'сундук'], 'territory': ['территория', 'выкупить', 'здание'], 'temple': ['храм', 'древний', 'руина'], 'enlightenment': ['просветление', 'отель', 'дом'], 'hat': ['шляпа', 'получить', 'турист'], 'moment': ['момент', 'секундочка', 'подождать'], 'sign': ['знак', 'вход', 'всё'], 'hill': ['холм', 'улучшить', 'ведьмин'], 'fail': ['остров', 'получиться', 'вернуться'], 'offer': ['предложение', 'уникальный', 'акция'], 'task': ['задание', 'задача', 'выполнить'], 'accept': ['принять', 'подарок', 'союз'], 'spooky': ['жуткий', 'шкатулка', 'открыть'], 'send': ['отправить', 'подарок', 'друг'], 'draw': ['ничья', 'необычный', 'ярко-красный'], 'robot': ['робот', 'работать', 'умный'], 'combination': ['комбинация', 'фишка', 'рядом'], 'download': ['загрузить', 'обновление', 'скачать'], 'connect': ['подключить', 'здание', 'faceb ...
# {'turtle': 'черепашонка',
#  'past': 'прошлое',
#  'head': 'голова',
#  'statuette': 'статуэтка',
#  'reduce': 'персонал',
#  'candy': 'леденец',
#  'shuttle': 'шаттл',
#  'bunch': 'букет',
#  'surprise': 'сюрприз',
#  'mistake': 'ошибка',
#  'area': 'восточный',
#  'bridge': 'мост',
#  'tea': 'чай',
#  'tap': 'нажать',
#  'heart': 'сердце',
#  'pirate': 'пиратский',
#  'clean': 'это',
#  'museum': 'музей',
#  'fairy': 'винтербелла',
#  'break': 'разбить',
#  'cake': 'кусочек',
#  'launch': 'событие',
#  'winner': 'победитель',
#  'merry': 'весёлый',
#  'lightning': 'молния',
#  'happen': 'случиться',
#  'score': 'набрать',
#  'mastery': 'мастерство',
#  'cozy': 'уютный',
#  'unioner': 'союз',
#  'jam': 'варение',
#  'news': 'новость',
#  'architect': 'кастлинга',
#  'expand': 'расширить',
#  'float': 'замок',
#  'package': 'зелёный',
#  'cruise': 'лайнер',
#  'florist': 'флорист',
#  'remove': 'извлечь',
#  'activate': 'активировать',
#  'health': 'здоровье',
#  'thank': 'это',
#  'design': 'чертёж',
#  'passion': 'страсть',
#  'meyer': 'мейер',
#  'lao': 'лао',
#  'friend': 'друг',
#  'tournament': 'турнир',
#  'chocolate': 'шоколадка',
#  'chance': 'шанс',
#  'chapter': 'сначала',
#  'water': 'вода',
#  'bear': 'мишка',
#  'yellow': 'жёлтый',
#  'journey': 'путешествие',
#  'error': 'ошибка',
#  'generator': 'генератор',
#  'celebration': 'праздник',
#  'bouquet': 'букет',
#  'rating': 'рейтинг',
#  'effort': 'усилие',
#  'touch': 'наш',
#  'difficulty': 'сложность',
#  'sinister': 'дуб',
#  'sunshine': 'солнечный',
#  'feeling': 'настроение',
#  'chameleon': 'хамелеон',
#  'leprechaun': 'лепреконовый',
#  'builder': 'строитель',
#  'vi': 'vi',
#  'sailor': 'матрос',
#  'click': 'сундук',
#  'territory': 'территория',
#  'temple': 'храм',
#  'enlightenment': 'дом',
#  'hat': 'турист',
#  'moment': 'подождать',
#  'sign': 'вход',
#  'hill': 'ведьмин',
#  'fail': 'получиться',
#  'offer': 'акция',
#  'task': 'задача',
#  'accept': 'принять',
#  'spooky': 'жуткий',
#  'send': 'отправить',
#  'draw': 'необычный',
#  'robot': 'робот',
#  'combination': 'рядом',
#  'download': 'обновление',
#  'connect': 'facebook',
#  'banish': 'призрак',
#  'surf': 'сёрфинг',
#  'abandon': 'забросить',
#  'flag': 'флаг',
#  'throw': 'вечеринка',
#  'restore': 'восстановить',
#  'grandpa': 'дедушка',
#  'success': 'успех',
#  'master': 'мастер',
#  'monkey': 'рия',
#  'believe': 'верить',
#  'traveler': 'экватор',
#  'rhee': 'рия',
#  'castle': 'улучшить',
#  'shine': 'всё',
#  'drop': 'получить',
#  'content': 'купить',
#  'check': 'посмотреть',
#  'hahaha': 'это',
#  'face': 'лицо',
#  'pack': 'paradise',
#  'swing': 'разгар',
#  'stone': 'камень',
#  'tourist': 'турист',
#  'video': 'видео',
#  'wow': 'это',
#  'craft': 'создание',
#  'message': 'сообщение',
#  'close': 'это',
#  'lamp': 'лампа',
#  'match': 'фишка',
#  'greet': 'поприветствовать',
#  'dark': 'это',
#  'competition': 'чемпион',
#  'attempt': 'попытка',
#  'mano': 'мано',
#  'color': 'цвет',
#  'butterfly': 'бабочка',
#  'penguin': 'пингвин',
#  'collection': 'прибыль',
#  'wind': 'ветер',
#  'hearty': 'кафе',
#  'accessory': 'аксессуар',
#  'progress': 'прогресс',
#  'flower': 'цветок',
#  'receive': 'получить',
#  'dwarf': 'найти',
#  'dragon': 'дракон',
#  'stop': 'остановиться',
#  'invitation': 'приглашение',
#  'great': 'отличный',
#  'gift': 'подарок',
#  'supply': 'запас',
#  'thing': 'всё',
#  'bring': 'принести',
#  'visit': 'посетить',
#  'salon': 'красота',
#  'forest': 'лесной',
#  'faq': 'faq',
#  'championship': 'чемпионат',
#  'deed': 'добрый',
#  'magic': 'магия',
#  'captain': 'капитан',
#  'open': 'открыть',
#  'chat': 'сообщение',
#  'jack': 'матрос',
#  'claus': 'рождественский',
#  'cub': 'джунгли',
#  'cupid': 'подарок',
#  'fan': 'яркий',
#  'portal': 'портал',
#  'brush': 'кисть',
#  'eek': 'паук',
#  'load': 'идти',
#  'information': 'информация',
#  'sunset': 'гонка',
#  'golem': 'разрушить',
#  'sale': 'распродажа',
#  'house': 'дом',
#  'treat': 'угостить',
#  'min': 'мина',
#  'cat': 'кот',
#  'write': 'дневник',
#  'rescue': 'остров',
#  'mean': 'это',
#  'press': 'кнопка',
#  'dao': 'дао',
#  'tell': 'это',
#  'coin': 'монета',
#  'happiness': 'счастие',
#  'plan': 'план',
#  'elf': 'эльф',
#  'seahorse': 'конёк',
#  'slice': 'кафе',
#  'dorin': 'дорин',
#  'fruit': 'фрукт',
#  'race': 'гонка',
#  'ha': 'это',
#  'aeronaut': 'аэронавт',
#  'basket': 'корзинка',
#  'access': 'палатка',
#  'ask': 'попросить',
#  'autumn': 'осень',
#  'cha': 'собирать',
#  'giraffe': 'знать',
#  'pizza': 'пицца',
#  'plantation': 'плантация',
#  'road': 'здание',
#  'minute': 'процесс',
#  'pyramid': 'пирамида',
#  'win': 'победит',
#  'course': 'хотеть',
#  'warehouse': 'склад',
#  'finish': 'завершить',
#  'hour': 'час',
#  'chain': 'разбить',
#  'turn': 'превратить',
#  'sidney': 'сидень',
#  'snack': 'провести',
#  'sabrina': 'сабрина',
#  'refill': 'пополнить',
#  'feather': 'перо',
#  'right': 'это',
#  'tool': 'инструмент',
#  'upgrade': 'улучшить',
#  'electricity': 'электричество',
#  'tutorial': 'остров',
#  'snowball': 'снежный',
#  'future': 'будущее',
#  'bonus': 'island',
#  'pro': 'битва',
#  'christma': 'рождественский',
#  'disco': 'танец',
#  'professor': 'крейза',
#  'fight': 'битва',
#  'case': 'кейс',
#  'turkey': 'это',
#  'remind': 'напоминать',
#  'accumulation': 'ускорить',
#  'ultrabonus': 'ультра',
#  'mood': 'настроение',
#  'explosion': 'просто',
#  'teddy': 'мишка',
#  'earth': 'земля',
#  'shell': 'ракушка',
#  'fish': 'рыба',
#  'sun': 'солнце',
#  'lesson': 'урок',
#  'keeper': 'хранитель',
#  'sandy': 'пляжный',
#  'emerald': 'открыть',
#  'windmill': 'ветряк',
#  'fit': 'подойти',
#  'shuffle': 'слышать',
#  'player': 'игрок',
#  'bavarian': 'гостиница',
#  'consumption': 'снизить',
#  'spring': 'весна',
#  'purchase': 'покупка',
#  'opponent': 'противник',
#  'candle': 'торт',
#  'recognize': 'узнать',
#  'coconut': 'кокосовый',
#  'group': 'общий',
#  'matter': 'дело',
#  'grow': 'мано',
#  'earn': 'получить',
#  'halloween': 'хэллоуин',
#  'wrong': 'пойти',
#  'truck': 'мороженщик',
#  'light': 'огонь',
#  'athlete': 'спортсмен',
#  'workshop': 'сундук',
#  'wonder': 'интересно',
#  'ocean': 'океан',
#  'valentine': 'валентина',
#  'mansion': 'особняк',
#  'select': 'выбрать',
#  'knot': 'удача',
#  'spend': 'тратить',
#  'independence': 'независимость',
#  'bitey': 'открыть',
#  'cosmo': 'космобокс',
#  'monster': 'монстр',
#  'dance': 'танец',
#  'miss': 'остров',
#  'dinner': 'ужин',
#  'alright': 'всё',
#  'paradise': 'paradise',
#  'building': 'здание',
#  'alien': 'пришелец',
#  'summon': 'позвать',
#  'clockwork': 'заводной',
#  'hire': 'нанять',
#  'grand': 'гранд',
#  'time': 'время',
#  'mark': 'стоить',
#  'comfort': 'символ',
#  'fuel': 'топливо',
#  'island': 'остров',
#  'nature': 'природа',
#  'egg': 'яйцо',
#  'sanctuary': 'аурум',
#  'love': 'любовь',
#  'fun': 'веселие',
#  'power': 'сила',
#  'fall': 'призрак',
#  'bag': 'сумка',
#  'ad': 'посмотреть',
#  'wish': 'пожелание',
#  'bamboo': 'бамбук',
#  'pot': 'золото',
#  'jellyfish': 'медузка',
#  'await': 'ждать',
#  'return': 'остров',
#  'pineapple': 'кафе',
#  'learn': 'узнать',
#  'embassy': 'посольство',
#  'science': 'наука',
#  'present': 'подарок',
#  'cut': 'лиана',
#  'goal': 'награда',
#  'cocktail': 'коктейль',
#  'blueprint': 'чертёж',
#  'say': 'говорить',
#  'snowflake': 'снежинка',
#  'totem': 'тотем',
#  'rocket': 'ракета',
#  'story': 'рассказать',
#  'pub': 'паб',
#  'animal': 'остров',
#  'ii': 'ii',
#  'star': 'здание',
#  'require': 'требоваться',
#  'look': 'искать',
#  'accumulate': 'накопить',
#  'burn': 'секунда',
#  'apple': 'яблоко',
#  'claim': 'забрать',
#  'beach': 'битва',
#  'snow': 'полный',
#  'end': 'битва',
#  'toy': 'игрушка',
#  'refresh': 'ассортимент',
#  'trick': 'хитрость',
#  'patrick': 'святой',
#  'paw': 'лапка',
#  'wooo': 'прошлый',
#  'panda': 'рыжий',
#  'request': 'заявка',
#  'spirit': 'дух',
#  'black': 'чёрный',
#  'cup': 'кофе',
#  'micro': 'микро',
#  'red': 'рыжий',
#  'party': 'вечеринка',
#  'century': 'век',
#  'icon': 'нажать',
#  'sure': 'хотеть',
#  'today': 'сегодня',
#  'list': 'игрок',
#  'attraction': 'прибыль',
#  'aurum': 'аурум',
#  'life': 'жизнь',
#  'ally': 'союзник',
#  'update': 'обновление',
#  'diving': 'дайвер',
#  'joy': 'радость',
#  'hunt': 'поиск',
#  'feature': 'выбрать',
#  'witch': 'ведьма',
#  'wait': 'дождаться',
#  'know': 'знать',
#  'watch': 'посмотреть',
#  'sub': 'подлодка',
#  'cancel': 'снос',
#  'business': 'дело',
#  'club': 'турклуб',
#  'catch': 'поймать',
#  'baby': 'малыш',
#  'convention': 'слёт',
#  'vine': 'лиана',
#  'slot': 'ячейка',
#  'try': 'попробовать',
#  'feel': 'чувствовать',
#  'construct': 'строить',
#  'king': 'король',
#  'dream': 'сбываться',
#  'decoration': 'украшение',
#  'hourglass': 'часы',
#  'farmer': 'фермер',
#  'sea': 'приключение',
#  'mr': 'мистер',
#  'vampire': 'вампир',
#  'max': 'остров',
#  'use': 'использовать',
#  'owner': 'владелец',
#  'poach': 'всмятку',
#  'energy': 'энергия',
#  'starfish': 'звезда',
#  'room': 'здание',
#  'key': 'ключ',
#  'trouble': 'беда',
#  'income': 'событие',
#  'ring': 'кольцо',
#  'damage': 'урон',
#  'add': 'друг',
#  'antique': 'шкатулка',
#  'process': 'процесс',
#  'dynamite': 'динамит',
#  'silver': 'серебряный',
#  'prize': 'приз',
#  'like': 'хотеть',
#  'word': 'слово',
#  'ride': 'прокатиться',
#  'pick': 'пирс',
#  'search': 'волна',
#  'collect': 'собрать',
#  'booster': 'бустер',
#  'evening': 'вечер',
#  'cracker': 'ракета',
#  'parrot': 'попугай',
#  'round': 'розовый',
#  'yacht': 'яхта',
#  'mega': 'мег',
#  'repair': 'ремонт',
#  'clock': 'вечность',
#  'kitty': 'видеть',
#  'recipe': 'открыться',
#  'palace': 'дворец',
#  'lose': 'искать',
#  'run': 'пройти',
#  'feed': 'накормить',
#  'lock': 'ключ',
#  'development': 'развитие',
#  'rub': 'пузико',
#  'conveyor': 'конвейер',
#  'residence': 'обитель',
#  'kind': 'турист',
#  'train': 'поезд',
#  'connection': 'интернет',
#  'crate': 'ящик',
#  'haha': 'это',
#  'banana': 'банановый',
#  'gallery': 'улучшение',
#  'hologram': 'свобода',
#  'reach': 'уровень',
#  'treasure': 'кладоискатель',
#  'way': 'путь',
#  'grape': 'виноград',
#  'bakery': 'кондитерский',
#  'medal': 'медаль',
#  'tom': 'маккензи',
#  'grain': 'зерно',
#  'reserve': 'ошибка',
#  'pay': 'заплатить',
#  'monument': 'статуя',
#  'middle': 'восточный',
#  'tropic': 'тропик',
#  'holiday': 'праздник',
#  'help': 'помочь',
#  'rock': 'дерево',
#  'facebook': 'facebook',
#  'ship': 'корабль',
#  'leaderboard': 'рейтинг',
#  'begin': 'начать',
#  'tower': 'стела',
#  'stay': 'остаться',
#  'hit': 'решающий',
#  'construction': 'строительство',
#  'year': 'год',
#  'elite': 'элитный',
#  'device': 'фотография',
#  'creation': 'сила',
#  'symbol': 'символ',
#  'boat': 'катер',
#  'bottle': 'вода',
#  'box': 'шкатулка',
#  'market': 'ярмарка',
#  'hide': 'прятки',
#  'log': 'отключить',
#  'suitcase': 'потерянный',
#  'leave': 'хотеть',
#  'amour': 'принцесса',
#  'maximum': 'максимальный',
#  'inn': 'гостиница',
#  'seeker': 'получить',
#  'phoenix': 'феникс',
#  'expert': 'мастер',
#  'field': 'поле',
#  'night': 'ночь',
#  'fortune': 'фортуна',
#  'paint': 'краска',
#  'coupon': 'купон',
#  'drink': 'пить',
#  'giant': 'морской',
#  'oak': 'дуб',
#  'experience': 'опыт',
#  'essence': 'эссенция',
#  'piggy': 'купить',
#  'guest': 'гость',
#  'contest': 'конкурс',
#  'snowman': 'снеговик',
#  'fund': 'недостаточно',
#  'memory': 'память',
#  'inventor': 'изобретатель',
#  'defeat': 'призрак',
#  'aquarium': 'аквариум',
#  'anchor': 'чемпион',
#  'smile': 'фестиваль',
#  'xiv': 'битва',
#  'dog': 'фургончик',
#  'meditation': 'медитация',
#  'badge': 'бейдж',
#  'air': 'воздух',
#  'eye': 'глаз',
#  'home': 'дом',
#  'enemy': 'противник',
#  'farming': 'фермерский',
#  'perfect': 'идеально',
#  'laugh': 'смех',
#  'factory': 'улучшить',
#  'naomi': 'наоми',
#  'land': 'территория',
#  'team': 'команда',
#  'coral': 'коралл',
#  'set': 'набор',
#  'harvest': 'праздник',
#  'bite': 'перекусить',
#  'st': 'святой',
#  'confirm': 'нажать',
#  'sand': 'это',
#  'miracle': 'рождественский',
#  'result': 'результат',
#  'bar': 'панель',
#  'duel': 'дуэль',
#  'book': 'сказать',
#  'store': 'магазин',
#  'sack': 'подарок',
#  'leopard': 'леопард',
#  'bunny': 'кролик',
#  'day': 'день',
#  'detective': 'детектив',
#  'sam': 'обмен',
#  'paper': 'бумажный',
#  'easter': 'пасхальный',
#  'santa': 'сант',
#  'cloud': 'облако',
#  'solo': 'задание',
#  'glass': 'мочь',
#  'inspiration': 'улучшение',
#  'meet': 'встреча',
#  'panther': 'пантера',
#  'achievement': 'достижение',
#  'generosity': 'щедрость',
#  'continue': 'продолжаться',
#  'mouse': 'заводной',
#  'hand': 'рука',
#  'produce': 'вырабатывать',
#  'pet': 'кролик',
#  'tour': 'экскурсия',
#  'bank': 'кристалл',
#  'class': 'занятие',
#  'wave': 'волна',
#  'statue': 'статуя',
#  'splash': 'аттракцион',
#  'ranking': 'рейтинг',
#  'glory': 'слава',
#  'unlock': 'достижение',
#  'universe': 'вселенная',
#  'decorate': 'украсить',
#  'shoe': 'турист',
#  'cheer': 'всё',
#  'resource': 'ресурс',
#  'welcome': 'пожаловать',
#  'bandage': 'бинт',
#  'congratulation': 'награда',
#  'festival': 'спортивный',
#  'zombie': 'прогнать',
#  'moon': 'луна',
#  'taste': 'вкус',
#  'dolphin': 'остров',
#  'renaissance': 'ренессанс',
#  'money': 'деньга',
#  'tab': 'раздел',
#  'clover': 'клевер',
#  'plant': 'электростанция',
#  'buy': 'территория',
#  'operation': 'операция',
#  'shop': 'магазин',
#  'boom': 'бум',
#  'recreation': 'парк',
#  'blow': 'взорвать',
#  'celebrate': 'отпраздновать',
#  'spell': 'заклинание',
#  'scare': 'прогнать',
#  'window': 'окно',
#  'complete': 'задание',
#  'choose': 'выбрать',
#  'toadstool': 'безопасный',
#  'item': 'предмет',
#  'queen': 'королева',
#  'winter': 'зимний',
#  'planner': 'час',
#  'battle': 'битва',
#  'attention': 'внимание',
#  'piece': 'комбинация',
#  'share': 'делиться',
#  'hero': 'сокровище',
#  'speedboat': 'гоночный',
#  'member': 'союз',
#  'stuff': 'всё',
#  'tonic': 'тоник',
#  'champion': 'чемпион',
#  'arrive': 'терпение',
#  'hall': 'зал',
#  'attract': 'привлекать',
#  'game': 'игра',
#  'purr': 'удача',
#  'map': 'карта',
#  'prepare': 'подготовиться',
#  'stamp': 'марка',
#  'cabin': 'хижина',
#  'create': 'союз',
#  'bundle': 'крошечный',
#  'picture': 'фотография',
#  'cream': 'мороженое',
#  'invite': 'друг',
#  'walk': 'остров',
#  'contain': 'предмет',
#  'hooray': 'ура',
#  'mini': 'волна',
#  'hunter': 'кладоискатель',
#  'tree': 'дерево',
#  'school': 'школа',
#  'cook': 'кулинарный',
#  'tulip': 'тюльпан',
#  'smell': 'чай',
#  'victory': 'победа',
#  'charge': 'зарядить',
#  'bird': 'птица',
#  'ruin': 'разрушить',
#  'eat': 'съесть',
#  'jar': 'удача',
#  'tent': 'получить',
#  'unicorn': 'единорог',
#  'quantum': 'электростанция',
#  'effect': 'эффект',
#  'pink': 'розовый',
#  'medium': 'средний',
#  'point': 'союз',
#  'rank': 'рейтинг',
#  'station': 'электростанция',
#  'card': 'карта',
#  'spider': 'паук',
#  'requirement': 'персонал',
#  'royal': 'музей',
#  'want': 'хотеть',
#  'join': 'союз',
#  'step': 'шаг',
#  'beauty': 'красота',
#  'souvenir': 'сувенир',
#  'eco': 'улучшить',
#  'vii': 'битва',
#  'lantern': 'фонарь',
#  'sell': 'продать',
#  'entertainment': 'развлекательный',
#  'liberty': 'свобода',
#  'good': 'хороший',
#  'think': 'думать',
#  'unit': 'блок',
#  'pilgrim': 'пилигрим',
#  'challenge': 'хороший',
#  'limit': 'превысить',
#  'real': 'настоящий',
#  'button': 'кнопка',
#  'diary': 'дневник',
#  'man': 'знать',
#  'breath': 'отель',
#  'resort': 'курорт',
#  'destroy': 'разрушить',
#  'park': 'улучшить',
#  'bouncy': 'надувной',
#  'cookie': 'печенька',
#  'cool': 'это',
#  'space': 'космический',
#  'vase': 'аурум',
#  'read': 'почитать',
#  'mile': 'гоночный',
#  'stock': 'накопить',
#  'adventure': 'морской',
#  'idea': 'идея',
#  'stick': 'флешка',
#  'participate': 'битва',
#  'luxury': 'роскошь',
#  'drill': 'бур',
#  'fly': 'улететь',
#  'demolition': 'отменить',
#  'discount': 'скидка',
#  'pumpkin': 'тыквенный',
#  'travel': 'гоночный',
#  'work': 'работа',
#  'row': 'подряд',
#  'cap': 'фишка',
#  'talisman': 'ошибка',
#  'jay': 'мочь',
#  'follow': 'достижение',
#  'letter': 'сант',
#  'demolish': 'здание',
#  'luck': 'пузырёк',
#  'sound': 'ошибка',
#  'project': 'проект',
#  'play': 'играть',
#  'hear': 'слышать',
#  'ball': 'бал',
#  'john': 'джон',
#  'sport': 'спортивный',
#  'preparation': 'подготовка',
#  'forget': 'забыть',
#  'harmony': 'гармония',
#  'weapon': 'оружие',
#  'arrival': 'прибытие',
#  'build': 'здание',
#  'honey': 'мёд',
#  'improve': 'привлекать',
#  'people': 'человек',
#  'music': 'музыка',
#  'friendship': 'дружелюбие',
#  'easterson': 'пасхалкин',
#  'increase': 'увеличить',
#  'deal': 'урон',
#  'exhibition': 'выставка',
#  'gear': 'шестерёнка',
#  'speed': 'ускорить',
#  'talk': 'пообщаться',
#  'test': 'круто',
#  'cost': 'стоимость',
#  'sky': 'кристалл',
#  'mystery': 'загадочный',
#  'wondershop': 'лавка',
#  'tasty': 'вкусный',
#  'planet': 'планета',
#  'union': 'союз',
#  'leader': 'лидер',
#  'internet': 'интернет',
#  'ear': 'знать',
#  'cute': 'это',
#  'level': 'уровень',
#  'research': 'исследование',
#  'bungalow': 'бунгало',
#  'kettlebell': 'гиря',
#  'hammer': 'молоточек',
#  'citadel': 'улучшить',
#  'calm': 'успокоить',
#  'opportunity': 'возможность',
#  'scientist': 'учёный',
#  'wealth': 'богатство',
#  'hold': 'провести',
#  'barrel': 'бочка',
#  'enjoy': 'остров',
#  'kit': 'paradise',
#  'bunche': 'гроздь',
#  'meow': 'заводной',
#  'hope': 'надеяться',
#  'legend': 'легенда',
#  'gain': 'получить',
#  'lover': 'аллея',
#  'shark': 'акула',
#  'sculpture': 'скульптура',
#  'fountain': 'фонтан',
#  'strike': 'комбо',
#  'dinosaur': 'это',
#  'summer': 'призрак',
#  'trade': 'обмен',
#  'green': 'зелёный',
#  'sphere': 'сила',
#  'start': 'начать',
#  'cart': 'тачка',
#  'pepper': 'сочный',
#  'worker': 'рабочий',
#  'save': 'спасти',
#  'turtilliada': 'тортильяд',
#  'pearl': 'жемчужина',
#  'center': 'центр',
#  'world': 'мир',
#  'staff': 'персонал',
#  'profit': 'прибыль',
#  'balance': 'баланс',
#  'coffee': 'кофе',
#  'live': 'жить',
#  'tablet': 'скрижаль',
#  'lot': 'участок',
#  'pier': 'пирс',
#  'manage': 'удаться',
#  'jungle': 'остров',
#  'birthday': 'рождение',
#  'super': 'супер',
#  'support': 'поддержка',
#  'villa': 'улучшить',
#  'fame': 'рейтинг',
#  'shaman': 'шаман',
#  'archeologist': 'археолог',
#  'obtain': 'получить',
#  'cafe': 'кафе',
#  'battery': 'батарейка',
#  'delicious': 'вкусный',
#  'boutique': 'бутик',
#  'twilight': 'сундук',
#  'chest': 'сундук',
#  'gold': 'золото',
#  'make': 'остров',
#  'ghost': 'призрак',
#  'ridge': 'гряда',
#  'crystal': 'кристалл',
#  'count': '…',
#  'coffer': 'тайник',
#  'excellent': 'отличный',
#  'frost': 'джон',
#  'record': 'распродажа',
#  'rate': 'игра',
#  'combo': 'комбо',
#  'diner': 'закусочный',
#  'change': 'изменение',
#  'princess': 'принцесса',
#  'season': 'пляжный',
#  'event': 'событие',
#  'reward': 'награда',
#  'type': 'тип',
#  'enter': 'ввести',
#  'let': 'давать',
#  'restaurant': 'ресторан',
#  'hurry': 'научный',
#  'photo': 'фото',
#  'strawberry': 'кексик',
#  'organize': 'организовать',
#  'bug': 'багз',
#  'guy': 'человек',
#  'care': 'забота',
#  'quest': 'задание',
#  'firework': 'фейерверк',
#  'viii': 'битва',
#  'technician': 'роботехника',
#  'dessert': 'десерт',
#  'need': 'нужный',
#  'ice': 'лёд',
#  'deluxe': 'отель',
#  'number': 'максимальный',
#  'stage': 'этап',
#  'hotel': 'отель',
#  'come': 'прийти',
#  'snatchin': 'снэтчин',
#  'rainbow': 'радуга',
#  'action': 'действие',
#  'fennec': 'фенек',
#  'place': 'место',
#  'gingerbread': 'пряник'}

# %%
import pickle
with open('termbase_unigrams_X.pkl', 'wb') as f:
       pickle.dump(termbase, f)

# %%
with open('termbase_3_X.pkl', 'wb') as f:
       pickle.dump(keyvsru, f)
